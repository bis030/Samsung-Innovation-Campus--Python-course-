# %%
print("hello")

print ("area is ", area , "peri is " , peri)

print(f " area is {area} peri is {peri} ")
# Out:
# hello

# %%
1 + 1
# Out:
# 2

# %%
#data types - int ,float 
10.0 + 2
# Out:
# 12.0

# %%
12//5
12/5
12%5
# Out:
# 2

# %%
"j" * 3
# Out:
# 'jjj'

# %%
#multi line
"""helgglo 
world"""

"hello \
world "
# Out:
# 'hello world '

# %%
#variables

a = 1
A = 1
PI = 3.14

my_variable= "ram"
myVar = 6 # not pythonic

# %%
#pep 8 - document to improve python coding

# give space around =
# small let for variables , capital A for constant
# naming : snake case

# %%
# input
# input("enter you name ") // this return smthng so store in a variable

name = input("enter you name ")  # returned value is in string form
age = int (input("enter age "))
print("name is " , name )
print(age + 10 )
# Out:
# enter you name  kll
# enter age  9
# name is  kll
# 19

# %%
# qn 1

radius = float(input("enter radius ") )

area = 3.14 * radius*radius
peri = 2*3.14*radius

print ("area is ", area)

print ("peri is ", peri)
print ("area is ", area , "peri is " , peri)
print(f"area is {area} peri is {peri} ")
# Out:
# enter radius  1
# area is  3.14
# peri is  6.28
# area is  3.14 peri is  6.28
# area is 3.14 peri is 6.28

# %%
# dont use keywords as variables , variables will over ride the 
#and keywords wont work

print = 3
int = 5
a=5

# sum_ , total , instead of sun

# %%
del print
del int

del a

# values are stored even when we are in another cell
# either restart kernal or use del
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 del print
#       2 del int
#       4 print(a)
#
# NameError: name 'print' is not defined

# %%
a="python "
a[1],a[4]
# Out:
# ('y', 'o')

# %%
b="PYTHON"

b[0:-2] , b[0:5:-2] , b[5:0:-2], b[-1:-4], b[-1: :-1]
# Out:
# ('PYTH', '', 'NHY', '', 'NOHTYP')

# %%
b="PYTHON"
b[0:], b[:4], b[-1: :-1]

#string reverse 
b[-1: :-1] , b[::-1]   

# when it sees minus in step , it automatically takes the right side as start
# Out:
# ('NOHTYP', 'NOHTYP')

# %%
b="PYTHON"

b[0:-2] # converts the negative index to positive equivalent
# Out:
# 'PYTH'

# %%
type("var")

# string is a object , so it has data members and ftns of it
# Out:
# str

# %%
dir("anystr")  # to seee the list of ftns applicable to string objects
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
my_str = "ramesh"

print(my_str.capitalize() ) #only first
print(my_str.upper() ) 
print(my_str.isalpha() )
# Out:
# Ramesh
# RAMESH
# True

# %%
stur = " My name is Bis "
print( stur.zfill(50))
print( stur.strip())
print( stur.split())
print( stur.rstrip())

print("test1\ntest2".split())

print("test1\ntest2".split("s"))

print ("this is a test string 123".split("test"))
# Out:
# 0000000000000000000000000000000000 My name is Bis
# My name is Bis
# ['My', 'name', 'is', 'Bis']
#  My name is Bis
# ['test1', 'test2']
# ['te', 't1\nte', 't2']
# ['this is a ', ' string 123']

# %%
my_str = "ramesh"

my_str.__dir__()
# Out:
# ['__new__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__iter__',
#  '__mod__',
#  '__rmod__',
#  '__len__',
#  '__getitem__',
#  '__add__',
#  '__mul__',
#  '__rmul__',
#  '__contains__',
#  'encode',
#  'replace',
#  'split',
#  'rsplit',
#  'join',
#  'capitalize',
#  'casefold',
#  'title',
#  'center',
#  'count',
#  'expandtabs',
#  'find',
#  'partition',
#  'index',
#  'ljust',
#  'lower',
#  'lstrip',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rstrip',
#  'rpartition',
#  'splitlines',
#  'strip',
#  'swapcase',
#  'translate',
#  'upper',
#  'startswith',
#  'endswith',
#  'removeprefix',
#  'removesuffix',
#  'isascii',
#  'islower',
#  'isupper',
#  'istitle',
#  'isspace',
#  'isdecimal',
#  'isdigit',
#  'isnumeric',
#  'isalpha',
#  'isalnum',
#  'isidentifier',
#  'isprintable',
#  'zfill',
#  'format',
#  'format_map',
#  '__format__',
#  'maketrans',
#  '__sizeof__',
# ...

# %%
my_str = "ramesh"

my_str.capitalize()  # press shift tab to view documentation

# help( my_str.lstrip() )   #to view documentation
# Out:
# 'Ramesh'

# %%
"MR.Ram".strip("MR.") # it takes every thing as character inside the bracket and checks for every character
# Out:
# 'am'

# %%
"MR.Ram".lstrip("MR.")
# Out:
# 'am'
