# %%
# sum += n exists
# sum ++ doesnt exist
# sum ** 2    square

# %%
#exception handling

#try , except


try :
    x=int(input("enter a number"))
    print("num is ",x)
except:
    print("plz enter a valid number")
# Out:
# enter a numberrew
# plz enter a valid number

# %%
# take birth year and show current age , if invalid input , again ask to enter age



while True :
    try :

        year = int(input("enter birth year"))
        age=2026-year



    except :
        print("please enter valid year")

    else:
        if age>0 and year<2026 and year>0 :
          print("age is valid",age)
          break
        print("enter a valid age ")
# Out:
# enter a valid age

# %%
except ValueError :

  # value type ko error aaye maatra catch garxa yo block le , aru sab exception block le garxa

except exception as e:
  # all other errors than defined avobe is catched by this

# %%
# data structure vs data type
- when complexity increase , data structure become more helpful


# data structures are very important part of python , and very useful for programmers

# array /// LIst - it is called list in pythin

- no need to define datatype and size in python , it is dynamic by default
- diff values can be of different dataype

x[]= [1,2,3]

# %%
x= [1,2,3]


x[1]
x[0:3]

# %%
c= [1,2.5, "ram", [1,2,3,4], 'c']

for x in c:
  print(x)


  c= [1,2.5, "ram", [1,2,3,4], 'c']

for x in range(len(c)): # thhis also gives same output but in pythonic way
  print(x)

# %%
# list vs string
- string is immutable
- list is mutable
- functions for both are also different

# %%
a= "12345"
a[0]=0   # error

# %%
a=[1,2,3,4]
a[0]=0 #corecct

# %%
# operations possible in list
- update
- add two list
- multiply with a list
- append vs extend in list

# %%
x=[1,2,3,4]
y=[6,7,8,9]

print(x+y)
print(x*2) # two times print that list in a new array

# %%
#append() method is used to add a single element to the end of a list.
# This element can be any data type, a number, a string, another list, or even an object.
# extend() method is used to add all elements from an iterable (e.g., a list, tuple, or set) to the end of the current list as single elements.
#  Unlike append(), which adds an entire iterable as a single element,



# append can add intefer at last , but extend doesnt take a single integer , it can only add iterables

# %%
x=[1,2,3,4]
y=[6,7,8,9]

x.append(y)

x.append("year")
print(x)

x.extend(y)

x.extend("year") # 'y' , 'e' , stores each element inside a iterable

x.extend(555) #error

# %%
a= [[1,2,3],
 [4,5,6],          # indentation error comming
  [7,8,9]]

  for i in a:
    print(i)

for i in a:
    for j in i:
      print(j)

  for i in a:
    for j in i:
      print(j , end = ",")   # check output

# %%
a=[]
for i in range(10):
  a.append(i)
print(a)

# %%
# take marks of 3 student and give total score and average score

# take marks of 3 student and give total score and average score

marks =[]
std=[]
tot=[]
for i in range(3):
  std.append(input("enter name"))
  m=[]

  for j in range(3):

    m.append(int(input("enter marks")))

  sum_=0
  for x in m:
      sum_ +=x
 average= sum_ / 3
 print(std[i])
 print("sum is ",sum_, "avg is ",average)

  ########### there is some error in this code , fix it

# %%
# using fstring

x = 1

input(f " enter value of x : {x}")

i=1
y = "enter marks of std " + str(i)

input (y)  # input value is stored inside y
