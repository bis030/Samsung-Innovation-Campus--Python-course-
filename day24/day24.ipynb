# %%
import pandas as pd 
p_data = pd.period_range(start="2020-1-1" ,
                         end="2020-12-31" , 
                         periods=None ,
                         freq='M'                         
                        )

p_data
# Out:
# PeriodIndex(['2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#              '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12'],
#             dtype='period[M]')

# %%
pip install yfinance
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 735.7 kB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#   DEPRECATION: Building 'multitasking' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'multitasking'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15548 sha256=1123e2680da9df80c3d7b7c2a4cf68728cbb88c628d5c4cf1e63376bcee3ae01
#   Stored in directory: /home/bishhh/.cache/pip/wheels/1e/df/0f/e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
# Successfully built multitasking
# ...

# %%
import pandas as pd 
from datetime import date,time,datetime

import matplotlib.pyplot as plt

import yfinance as yf

df = yf.download("AAPL",start="2020-01-01" , end ="2023-01-01")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.400528   72.460791   71.156689   71.409793  135480400
# 2020-01-03   71.696648   72.455966   71.472469   71.629153  146322800
# 2020-01-06   72.267929   72.306499   70.568503   70.819201  118387200
# 2020-01-07   71.928047   72.533087   71.708687   72.277571  108872000
# 2020-01-08   73.085106   73.386423   71.631552   71.631552  132079200
# ...                ...         ...         ...         ...        ...
# 2022-12-23  129.778854  130.330013  127.593891  128.853688   63814900
# 2022-12-27  127.977745  129.335969  126.688423  129.306444   69007800
# 2022-12-28  124.050713  128.961953  123.883397  127.623418   85438400
# 2022-12-29  127.564384  128.420649  125.714059  125.969950   75703700
# ...

# %%
m5= df[("Close","AAPL")].rolling(window=5).mean()
m10= df[("Close","AAPL")].rolling(window=10).mean()
m120= df[("Close","AAPL")].rolling(window=120).mean()
m60= df[("Close","AAPL")].rolling(window=60).mean()

plt.figure(figsize=(15,10) )
plt.plot(Close, label="Close" ,  linewidth=5)
plt.plot(m5,lable="m5")
plt.plot(m10,lable="m10")
plt.plot(m60,lable="m60")
plt.plot(m120,lable="m120")

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       4 m60= df[("Close","AAPL")].rolling(window=60).mean()
#       6 plt.figure(figsize=(15,10) )
# ----> 7 plt.plot(Close, label="Close" ,  linewidth=5)
#       8 plt.plot(m5,lable="m5")
#       9 plt.plot(m10,lable="m10")
#
# NameError: name 'Close' is not defined

# %%
import matplotlib.pyplot as plt

world_total.plot(
